# %%
print("Name: Fatima Custodio Nepomuceno")
print("Course: Bachelor of Computer Studies")
print("Section: BSC3A")
print("Favorite AI Technology: favAI")
print("Future AI Project: futureAI")
# Out:
# Name: Fatima Custodio Nepomuceno
# Course: Bachelor of Computer Studies
# Section: BSC3A
# Favorite AI Technology: favAI
# Future AI Project: futureAI
